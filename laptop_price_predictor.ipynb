# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/laptop/laptop_data.csv

# %%
df = pd.read_csv('/kaggle/input/laptop/laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.drop(columns=['Unnamed: 0'], inplace= True)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
# EDA
import seaborn as sns
sns.distplot(df['Price'])
# Out:
# /tmp/ipykernel_36/2611447453.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# data is skewed
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
import matplotlib.pyplot as plt
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# /tmp/ipykernel_36/1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
# screen resolution
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df['TouchScreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df.sample(5)
# Out:
#      Company     TypeName  Inches             ScreenResolution  \
# 1185    Asus       Gaming    15.6  IPS Panel Full HD 1920x1080
# 63      Asus     Notebook    14.0            Full HD 1920x1080
# 493     Acer     Notebook    15.6                     1366x768
# 452       HP  Workstation    15.6  IPS Panel Full HD 1920x1080
# 512     Dell     Notebook    15.6            Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 1185  Intel Core i7 6700HQ 2.6GHz    8  256GB SSD +  1TB HDD
# 63     Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 493   AMD A10-Series 9620P 2.5GHz    8               1TB HDD
# 452   Intel Core i7 7820HQ 2.9GHz    8             512GB SSD
# 512    Intel Core i5 7200U 2.5GHz    8               1TB HDD
#
#                           Gpu       OpSys  Weight     Price  TouchScreen
# 1185  Nvidia GeForce GTX 960M  Windows 10   2.591  48431.52            0
# 63     Intel UHD Graphics 620  Windows 10   1.400  50136.48            0
# 493         AMD Radeon RX 540  Windows 10   2.200  30849.12            0
# 452     Intel HD Graphics 620  Windows 10   2.310  81731.52            0
# 512     Intel HD Graphics 620  Windows 10   2.180  44542.08            0

# %%
df['TouchScreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TouchScreen'>

# %%
sns.barplot(x=df['TouchScreen'],y=df['Price'])
# Out:
# <Axes: xlabel='TouchScreen', ylabel='Price'>

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand = True)
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]
df.sample(4)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 913       HP  Notebook    15.6            Full HD 1920x1080
# 52        HP  Notebook    15.6            Full HD 1920x1080
# 142   Lenovo    Gaming    15.6  IPS Panel Full HD 1920x1080
# 1201  Lenovo  Notebook    15.6                     1366x768
#
#                               Cpu  Ram     Memory                       Gpu  \
# 913    Intel Core i7 7500U 2.7GHz    8  256GB SSD      Nvidia GeForce 930MX
# 52      AMD A6-Series 9220 2.5GHz    4  256GB SSD    AMD Radeon R4 Graphics
# 142   Intel Core i7 7700HQ 2.8GHz    8  256GB SSD  Nvidia GeForce GTX 1050M
# 1201   Intel Core i7 6500U 2.5GHz    8  500GB HDD      Nvidia GeForce 920MX
#
#            OpSys  Weight       Price  TouchScreen  IPS  \
# 913   Windows 10    2.04  54291.7872            0    0
# 52    Windows 10    1.86  21231.5472            0    0
# 142        No OS    2.40  46300.3200            0    1
# 1201       No OS    2.20  33513.1200            0    0
#
#                        X_res Y_res
# 913             Full HD 1920  1080
# 52              Full HD 1920  1080
# 142   IPS Panel Full HD 1920  1080
# 1201                    1366   768

# %%
df['X_res']=df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#   X_res Y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# memory usage: 142.6+ KB

# %%
df['X_res']=df['X_res'].astype('int')
df['Y_res']=df['Y_res'].astype('int')
df.sample(4)
# Out:
#     Company   TypeName  Inches   ScreenResolution                         Cpu  \
# 16     Dell   Notebook    15.6  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 784  Lenovo  Ultrabook    14.0  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 929      HP   Notebook    14.0           1366x768  Intel Core i5 6200U 2.3GHz
# 484  Lenovo   Notebook    15.6           1366x768  Intel Core i3 6006U 2.0GHz
#
#      Ram     Memory                    Gpu       OpSys  Weight      Price  \
# 16     8  256GB SSD     AMD Radeon R5 M430  Windows 10    2.20   39693.60
# 784   16  512GB SSD  Intel HD Graphics 620  Windows 10    1.70  122490.72
# 929    4  500GB HDD  Intel HD Graphics 520  Windows 10    1.95   61218.72
# 484    4  128GB SSD  Intel HD Graphics 520  Windows 10    2.30   30103.20
#
#      TouchScreen  IPS  X_res  Y_res
# 16             0    0   1920   1080
# 784            0    0   1920   1080
# 929            0    0   1366    768
# 484            0    0   1366    768

# %%
# as X_res and Y_res have collinearity, so we will not be using it, instead we will have a new column named PPI.
df['PPI']=((df['X_res']**2 + df['Y_res']**2)**0.5/df['Inches']).astype('float')

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:' '.join(x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu Name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu Name      Cpu brand
# 0  226.983005  Intel Core i5  Intel Core i5
# 1  127.677940  Intel Core i5  Intel Core i5
# 2  141.211998  Intel Core i5  Intel Core i5
# 3  220.534624  Intel Core i7  Intel Core i7
# 4  226.983005  Intel Core i5  Intel Core i5

# %%
df['Cpu brand'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'], y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns = ['Cpu', 'Cpu Name'], inplace= True)
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS         PPI      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'], y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"] = new[0].str.strip()
df["second"] = new[1].fillna("0")

# Layer 1
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)


# Layer 2
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Now remove non-digits and convert to int
df['first'] = df['first'].str.replace(r'\D', '', regex=True).astype(int)
df['second'] = df['second'].str.replace(r'\D', '', regex=True).astype(int)

# Final memory columns
df["HDD"] = (df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"])
df["SSD"] = (df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"])
df["Hybrid"] = (df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"])

# %%
df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage', 'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS         PPI      Cpu brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage
# 0    0  128       0              0
# 1    0    0       0            128
# 2    0  256       0              0
# 3    0  512       0              0
# 4    0  256       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df[['Ram','Weight','TouchScreen','IPS','PPI','HDD','SSD','Hybrid','Flash_Storage']].corrwith(df['Price'])
# Out:
# Ram              0.743007
# Weight           0.210370
# TouchScreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# dtype: float64

# %%
df.drop(columns = ['Hybrid','Flash_Storage'], inplace = True)

# %%
df.sample(4)
# Out:
#      Company            TypeName  Ram                         Gpu       OpSys  \
# 631     Dell              Gaming   16  Nvidia GeForce GTX 1050 Ti  Windows 10
# 1122      HP            Notebook    8       Intel HD Graphics 520   Windows 7
# 552     Dell              Gaming   16     Nvidia GeForce GTX 1070  Windows 10
# 775     Asus  2 in 1 Convertible   12        Nvidia GeForce 940MX  Windows 10
#
#       Weight      Price  TouchScreen  IPS         PPI      Cpu brand   HDD  \
# 631     2.62   78801.12            0    0  141.211998  Intel Core i7  1000
# 1122    1.43   80612.64            0    0  157.350512  Intel Core i5     0
# 552     4.42  143802.72            0    1  127.335675  Intel Core i7  1000
# 775     2.30   44701.92            1    0  141.211998  Intel Core i7  2000
#
#       SSD
# 631   256
# 1122  256
# 552   256
# 775     0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])
df['Gpu brand']
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3         AMD
# 4       Intel
#         ...
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301      AMD
# 1302    Intel
# Name: Gpu brand, Length: 1303, dtype: object

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS         PPI      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
sns.barplot(x=df['Gpu brand'], y = df['Price'], estimator = np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns = ['Gpu'], inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  TouchScreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'], y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)
df.drop(columns=['OpSys'], inplace = True)
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  TouchScreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
sns.barplot(x=df['os'], y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# /tmp/ipykernel_36/1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'], y = df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df[['Weight']].corrwith(df['Price'])
# Out:
# Weight    0.209867
# dtype: float64

# %%
df[['Weight','Ram','Price','TouchScreen','IPS','PPI','HDD','SSD']].corrwith(df['Price'])
# Out:
# Weight         0.209867
# Ram            0.742905
# Price          1.000000
# TouchScreen    0.192917
# IPS            0.253320
# PPI            0.475368
# HDD           -0.096891
# SSD            0.670660
# dtype: float64

# %%
# Compute the correlation matrix
corr_matrix = df[['Weight','Ram','Price','TouchScreen','IPS','PPI','HDD','SSD']].corr()

# Plot the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
# target column is skewed, usko normal m convert krenge log transformation lga k
sns.distplot(np.log(df['Price']))
# Out:
# /tmp/ipykernel_36/3915161841.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# r2 score 85 se 90 hogya h ye change lgane p.....
X = df.drop(columns=['Price'])
y = np.log(df['Price'])
X
# Out:
#      Company            TypeName  Ram  Weight  TouchScreen  IPS         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 0             Intel Core i5     0  128     Intel                 Mac
# 1             Intel Core i5     0    0     Intel                 Mac
# 2             Intel Core i5     0  256     Intel  Others/No OS/Linux
# 3             Intel Core i7     0  512       AMD                 Mac
# 4             Intel Core i5     0  256     Intel                 Mac
# ...                     ...   ...  ...       ...                 ...
# 1298          Intel Core i7     0  128     Intel             Windows
# 1299          Intel Core i7     0  512     Intel             Windows
# 1300  Other Intel Processor     0    0     Intel             Windows
# 1301          Intel Core i7  1000    0       AMD             Windows
# 1302  Other Intel Processor   500    0     Intel             Windows
#
# [1302 rows x 12 columns]

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.15, random_state = 2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  TouchScreen  IPS         PPI  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 183           Intel Core i5     0  128     Intel             Windows
# 1141          Intel Core i7  1000  128    Nvidia             Windows
# 1049  Other Intel Processor     0    0     Intel  Others/No OS/Linux
# 1020          Intel Core i3  1000    0     Intel             Windows
# 878           Intel Core i5  1000  128    Nvidia             Windows
# ...                     ...   ...  ...       ...                 ...
# 466           Intel Core i3   500    0    Nvidia             Windows
# 299           Intel Core i7     0  512    Nvidia             Windows
# 493           AMD Processor  1000    0       AMD             Windows
# 527           Intel Core i3  2000    0    Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0    0     Intel                 Mac
#
# [1106 rows x 12 columns]

# %%
# Applying One Hot Encoding
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model  import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
# linear Regression
step1 = ColumnTransformer (transformers = [
    ('col_tnf',OneHotEncoder(sparse=False, drop = 'first'),[0,1,7,10,11])
], remainder = 'passthrough')
step2 = LinearRegression()
pipe = Pipeline([
    ('step1',step1),
    ('step2', step2)
])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test, y_pred))
print('mae',mean_absolute_error(y_test, y_pred))
# Out:
# R2 score 0.8073277448418641
# mae 0.210178279764288
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
np.exp(0.21)
# Out:
# 1.2336780599567432

# %%
# Ridge Regression
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8127331031311809
# MAE 0.20926802242582962
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# lasso
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071853945317105
# MAE 0.21114361613472565
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# KNN
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8027675291937718
# MAE 0.193456293739003
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Decision Tree
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8346064708730396
# MAE 0.18393533012976748

# %%
# SVM
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8083180902272435
# MAE 0.20239059427315706

# %%
# Random Forest
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %%
# Extra Trees
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                            bootstrap=True,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8850720167552375
# MAE 0.16154538000217084

# %%
# AdaBoost
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7986275764368574
# MAE 0.22270989348398845
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Gradient Boost
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8823073921955525
# MAE 0.15971948799468227

# %%
# XgBoost
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8771404806375558
# MAE 0.16262936288951352
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Voting Regressor
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15,bootstrap=True)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10,bootstrap=True)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8896394823667614
# MAE 0.15814540942280317

# %%
# Stacking
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8782988752666583
# MAE 0.16716924579273865

# %%
from sklearn.model_selection import RandomizedSearchCV


xgb_params = {
    'n_estimators': [int(x) for x in np.linspace(start=10, stop=200, num=10)],
    'max_depth': [int(x) for x in np.linspace(2, 30, num=5)],
    'learning_rate': [0.1, 0.01, 0.001],
    'subsample': [0.5, 0.7, 1.0],
    'colsample_bytree': [0.5, 0.7, 1.0],
    'gamma': [0, 1, 5],
    'reg_alpha': [0, 0.5, 1],
    'reg_lambda': [0, 0.5, 1]
}

X_train_cat = X_train.copy()

# Convert object columns to category
for col in X_train_cat.select_dtypes(include='object').columns:
    X_train_cat[col] = X_train_cat[col].astype('category')

xgb_random_search = RandomizedSearchCV(
    estimator=XGBRegressor(enable_categorical=True),
    param_distributions=xgb_params,
    n_iter=100,
    cv=3,
    verbose=2,
    random_state=0,
    n_jobs=-1
)

xgb_random_search.fit(X_train_cat, y_train)







# xgb_params = {
#     'n_estimators': [int(x) for x in np.linspace(start=10, stop=200, num=10)],
#     'max_depth': [int(x) for x in np.linspace(2, 30, num=5)],
#     'learning_rate': [0.1, 0.01, 0.001],
#     'subsample': [0.5, 0.7, 1.0],
#     'colsample_bytree': [0.5, 0.7, 1.0],
#     'gamma': [0, 1, 5],
#     'reg_alpha': [0, 0.5, 1],
#     'reg_lambda': [0, 0.5, 1]
# }

# xgb_random_search = RandomizedSearchCV(estimator=XGBRegressor(), param_distributions=xgb_params, n_iter=100, cv=3, verbose=2, random_state=0, n_jobs=-1)
# xgb_random_search.fit(X_train, y_train)

print(f"Best XGBoost model parameters: {xgb_random_search.best_params_}")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=178, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=200, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=200, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=200, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=157, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=157, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=157, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=9, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=9, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=9, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=94, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=157, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=157, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=16, n_estimators=157, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=52, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=16, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=178, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=16, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=16, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=136, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=136, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=136, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=73, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=73, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=73, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=2, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=2, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=2, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=52, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=52, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=52, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=178, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=94, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=157, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=16, n_estimators=157, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=31, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=16, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=52, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=52, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=94, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=94, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=115, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=115, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=115, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=178, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=178, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, n_estimators=157, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, n_estimators=157, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, n_estimators=157, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=94, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=157, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=16, n_estimators=157, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=52, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=31, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=23, n_estimators=52, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=30, n_estimators=73, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=73, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=94, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=157, reg_alpha=0.5, reg_lambda=0, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=157, reg_alpha=0.5, reg_lambda=0, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=52, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=10, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=10, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=10, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=157, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=157, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=52, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=31, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=16, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=178, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=178, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=16, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=52, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=73, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=73, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=10, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=10, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=16, n_estimators=136, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=16, n_estimators=136, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=23, n_estimators=52, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=157, reg_alpha=0.5, reg_lambda=0, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=136, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=94, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=94, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=94, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=23, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=23, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=23, n_estimators=31, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=200, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=200, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=200, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=136, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=136, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=73, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=73, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=115, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=10, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=10, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=9, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=52, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=178, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, n_estimators=157, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, n_estimators=157, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=94, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=94, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=178, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=178, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=136, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=136, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=30, n_estimators=10, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=30, n_estimators=10, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=10, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=10, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=10, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=9, n_estimators=136, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=2, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=2, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# ...
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=136, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=136, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=10, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=23, n_estimators=52, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=23, n_estimators=52, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=52, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=23, n_estimators=52, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.001, max_depth=23, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=2, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=30, n_estimators=10, reg_alpha=1, reg_lambda=1, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=200, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=73, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=2, n_estimators=178, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=30, n_estimators=136, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=115, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=30, n_estimators=115, reg_alpha=0, reg_lambda=0.5, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=157, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=157, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=9, n_estimators=52, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=30, n_estimators=52, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, n_estimators=73, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=94, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=178, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.001, max_depth=2, n_estimators=136, reg_alpha=1, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=2, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=2, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=23, n_estimators=31, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.001, max_depth=23, n_estimators=31, reg_alpha=1, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.1, max_depth=9, n_estimators=178, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=1, learning_rate=0.1, max_depth=9, n_estimators=31, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=23, n_estimators=178, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=9, n_estimators=10, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=9, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=9, n_estimators=94, reg_alpha=0.5, reg_lambda=1, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=115, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.1, max_depth=2, n_estimators=10, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.01, max_depth=16, n_estimators=94, reg_alpha=0, reg_lambda=0.5, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=136, reg_alpha=0, reg_lambda=0, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=30, n_estimators=10, reg_alpha=0.5, reg_lambda=0.5, subsample=0.5; total time=   0.0s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.001, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=1, learning_rate=0.01, max_depth=30, n_estimators=31, reg_alpha=0.5, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=5, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=1, reg_lambda=1, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=157, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=16, n_estimators=157, reg_alpha=1, reg_lambda=0.5, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0.5, reg_lambda=0, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.001, max_depth=2, n_estimators=157, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=5, learning_rate=0.001, max_depth=9, n_estimators=73, reg_alpha=0, reg_lambda=0.5, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=23, n_estimators=157, reg_alpha=0.5, reg_lambda=0, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=16, n_estimators=115, reg_alpha=0, reg_lambda=0, subsample=0.5; total time=   0.1sBest XGBoost model parameters: {'subsample': 1.0, 'reg_lambda': 0.5, 'reg_alpha': 0.5, 'n_estimators': 200, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.5}

# %%
best_xgb_model = XGBRegressor(**xgb_random_search.best_params_, enable_categorical=True)

best_xgb_model.fit(X_train_cat, y_train)
X_test_cat = X_test.copy()
for col in X_test_cat.select_dtypes(include='object').columns:
    X_test_cat[col] = X_test_cat[col].astype('category')
    
best_xgb_predictions = best_xgb_model.predict(X_test_cat)
best_xgb_mae = mean_absolute_error(y_test, best_xgb_predictions)
r2 = r2_score(y_test, best_xgb_predictions)
print(f"XGBoost Mean Absolute Error with best model: {best_xgb_mae}")
print(f"XGBoost r2 score with best model: {r2}")
# Out:
# XGBoost Mean Absolute Error with best model: 0.16436560715771809
# XGBoost r2 score with best model: 0.8852503814848027
